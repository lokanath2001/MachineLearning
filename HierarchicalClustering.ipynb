# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import scipy.cluster.hierarchy as sch
from sklearn.cluster import AgglomerativeClustering

# %%
dataset = pd.read_csv("data/Mall_customers.csv")
dataset.head()
# Out:
#    CustomerID  Gender  Age  Anuual_Income  Sepending
# 0           1    Male   19             15         39
# 1           2    Male   21             15         81
# 2           3  Female   20             16          6
# 3           4  Female   23             16         77
# 4           5  Female   31             17         40

# %%
dataset.isna().sum()
# Out:
# CustomerID       0
# Gender           0
# Age              0
# Anuual_Income    0
# Sepending        0
# dtype: int64

# %%
x=dataset[['Anuual_Income','Sepending']]
print(x)
# Out:
#      Anuual_Income  Sepending
# 0               15         39
# 1               15         81
# 2               16          6
# 3               16         77
# 4               17         40
# ..             ...        ...
# 195            120         79
# 196            126         28
# 197            126         74
# 198            137         18
# 199            137         83
#
# [200 rows x 2 columns]

# %%
X = dataset.iloc[: , 3: ].values

# %%
dendrogram = sch.dendrogram(sch.linkage(X , method='ward'))
plt.title('Dendrogram')
plt.xlabel('customer')
plt.ylabel('Euclidean')
plt.show()

# %%
hc = AgglomerativeClustering(n_clusters=5 , affinity='euclidean' , linkage='ward')
y_hc = hc.fit_predict(X)
# Out:
# /lib/python3.11/site-packages/sklearn/cluster/_agglomerative.py:1006: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
